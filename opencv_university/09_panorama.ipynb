# %% [markdown]
# # Creating Panoramas using OpenCV
#
# **Satya Mallick, LearnOpenCV.com**

# %%
# Import Libraries
import os
import cv2
import math
import glob
import numpy as np
import matplotlib.pyplot as plt

from zipfile import ZipFile
from urllib.request import urlretrieve

# %matplotlib inline

# %% [markdown]
# ##  <font style="color:black">Download Assets</font>

# %%
def download_and_unzip(url, save_path):
    print(f"Downloading and extracting assests....", end="")

    # Downloading zip file using urllib package.
    urlretrieve(url, save_path)

    try:
        # Extracting zip file using the zipfile package.
        with ZipFile(save_path) as z:
            # Extract ZIP file contents in the same directory.
            z.extractall(os.path.split(save_path)[0])

        print("Done")

    except Exception as e:
        print("\nInvalid file.", e)

# %%
URL = r"https://www.dropbox.com/s/0o5yqql1ynx31bi/opencv_bootcamp_assets_NB9.zip?dl=1"

asset_zip_path = os.path.join(os.getcwd(), "opencv_bootcamp_assets_NB9.zip")

# Download if assest ZIP does not exists.
if not os.path.exists(asset_zip_path):
    download_and_unzip(URL, asset_zip_path)
# Out:
# Downloading and extracting assests....Done

# %% [markdown]
# # Steps for Creating Panoramas
#
# 1. Find keypoints in all images
# 2. Find pairwise correspondences
# 2. Estimate pairwise Homographies
# 3. Refine Homographies
# 3. Stitch with Blending

# %% [markdown]
# # Steps for Creating Panoramas using OpenCV

# %%
# Read Images

imagefiles = glob.glob(f"boat{os.sep}*")
imagefiles.sort()


images = []
for filename in imagefiles:
    img = cv2.imread(filename)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    images.append(img)

num_images = len(images)

# %%
# Display Images
plt.figure(figsize=[30, 10])
num_cols = 3
num_rows = math.ceil(num_images / num_cols)
for i in range(0, num_images):
    plt.subplot(num_rows, num_cols, i + 1)
    plt.axis("off")
    plt.imshow(images[i])

# %% [markdown]
# Use the **sticher** class

# %%
# Stitch Images
stitcher = cv2.createStitcher()
status, result = stitcher.stitch(images)

if status == 0:
    plt.figure(figsize=[30, 10])
    plt.imshow(result)

# %%
result_gray = cv2.cvtColor(result, cv2.COLOR_RGB2GRAY)
_, mask = cv2.threshold(result_gray, 1, 255, cv2.THRESH_BINARY)
contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Check if contours were found
if contours:
    max_area = 0
    best_cnt = None
    for cnt in contours:
        area = cv2.contourArea(cnt)
        if area > max_area:
            max_area = area
            best_cnt = cnt
    x, y, w, h = cv2.boundingRect(best_cnt)
    result = result[y:y+h, x:x+w]
else:
    print("No contours found.")

plt.figure(figsize=[30, 10])
plt.imshow(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27484\3768754495.py in <module>
#       1 result_gray = cv2.cvtColor(result, cv2.COLOR_RGB2GRAY)
#       2 _, mask = cv2.threshold(result_gray, 1, 255, cv2.THRESH_BINARY)
# ----> 3 contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#       4
#       5 # Check if contours were found
#
# ValueError: too many values to unpack (expected 2)

# %%
result2 = remove_black_border(result)
plt.figure(figsize=[30, 10])
plt.imshow(result2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27484\923560877.py in <module>
# ----> 1 result2 = remove_black_border(result)
#       2 plt.figure(figsize=[30, 10])
#       3 plt.imshow(result2)
#
# ~\AppData\Local\Temp\ipykernel_27484\2278111182.py in remove_black_border(img)
#       4
#       5     # Find contours
# ----> 6     contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#       7
#       8     # Check if contours were found
#
# ValueError: too many values to unpack (expected 2)
